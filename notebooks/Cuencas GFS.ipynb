# %%
import geopandas as  gpd
import pandas as pd
import datetime
import glob
from rasterstats import zonal_stats

# %%
COLUM_REPLACE = {'Subcuenca': 'subcuenca', 'Cuenca': 'cuenca'}

# %%
def getList():
    return glob.glob('../geotiff/GFS_PPN_*.tiff', recursive=True)

# %%
def integrate_basins(basins_fp: str) -> gpd.GeoDataFrame:
    """
    This functions opens a geotiff with ppn data, converts to a raster,
    integrate the ppn into cuencas and returns a GeoDataFrame object.

    Parameters:
        cuencas_shp: Path to shapefile
    Returns:
        cuencas_gdf_ppn (GeoDataFrame): a geodataframe with cuerncas and ppn
    """

    cuencas_shp = '/home/sagus/Development/wrf-cuenca/src/shapefiles/cuencas_hidro_new.shp'
    cuencas_gdf: gpd.GeoDataFrame = gpd.read_file(cuencas_shp)
    df_zs = pd.DataFrame(zonal_stats(cuencas_shp, basins_fp))

    cuencas_gdf_ppn = pd.concat([cuencas_gdf, df_zs], axis=1).dropna(subset=['mean'])

    cuencas_gdf_ppn = cuencas_gdf_ppn.rename(columns=COLUM_REPLACE)

    return cuencas_gdf_ppn[['subcuenca', 'cuenca', 'geometry', 'count',
                            'max', 'min', 'mean']]

# %%
lista = getList()

# %%
lista.sort()

# %%
lista[1]
# Out:
# '../geotiff/GFS_PPN_2021-02-19Z21:00.tiff'

# %%
cuencas_gdf = integrate_basins(lista[1])
# Out:
# /home/sagus/anaconda3/envs/goes/lib/python3.8/site-packages/rasterstats/io.py:301: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
cuencas_gdf
# Out:
#                                   subcuenca                        cuenca  \
# 0                  01-Sistema San Francisco           Río Pasaje o Salado
# 1             02-Cuenca R. Quinto (Popopis)          Río Quinto (Popopis)
# 2                  03-Sistema A. La Punilla          Río Quinto (Popopis)
# 3                    04-Cuenca R. Anizacate             Lag. Mar Chiquita
# 4                    05-Cuenca A. La Cañada             Lag. Mar Chiquita
# 5                       06-Cuenca R. Saldán             Lag. Mar Chiquita
# 6                 07-Cuenca Emb Los Molinos             Lag. Mar Chiquita
# 7              09-Cuenca Emb. Piedras Moras                 Río Carcarañá
# 8                   10-Sistema Laguna del 7          Río Quinto (Popopis)
# 9           12-Sistema Bañados del R. Dulce             Lag. Mar Chiquita
# 10                      14-Sistema Morteros           Río Pasaje o Salado
# 11                     15-Sistema A. El Ají                 Río Carcarañá
# 12                 16-Sistema Canal El Gato                 Río Carcarañá
# 13                 17-Cuenca R. Jesús María             Lag. Mar Chiquita
# 14    18-Cuenca R. Carnero y R. Salsipuedes             Lag. Mar Chiquita
# 15                     20-Sistema A. Chucul                 Río Carcarañá
# 16               22-Sistema Canal Desviador                 Río Carcarañá
# 17                     23-Cuenca R. Totoral             Lag. Mar Chiquita
# 18                24-Cuenca A. La Cortadera               Salinas Grandes
# 19                25-Cuenca R. Cruz del Eje               Salinas Grandes
# 20                  26-Cuenca Emb. Pichanas               Salinas Grandes
# 21                    27-Sistema A. Tortuga                 Río Carcarañá
# 22          28-Cuenca R. Seco y A. Ischilín               Salinas Grandes
# 23             32-Cuenca R. de los Tártagos             Lag. Mar Chiquita
# 24                      33-Cuenca R. Bustos             Lag. Mar Chiquita
# 25  34-Cuenca A. Ancas Mayo y A. San Miguel             Lag. Mar Chiquita
# 26                  35-Cuenca R. Guasapampa               Salinas Grandes
# 27                      36-Sistema de Pocho               Salinas Grandes
# 28                    37-Sistema San Javier               Salinas Grandes
# 29                  38-Cuenca R. Guayacaste             Lag. Mar Chiquita
# 30                       39-Cuenca R. Junta             Lag. Mar Chiquita
# 31                   40-Sistema A. El Chato                 Río Carcarañá
# 32                    42-Cuenca R. Pichanas               Salinas Grandes
# 33                     43-Sistema A. Chazón                 Río Carcarañá
# 34               44-Cuenca R. de los Sauces               Salinas Grandes
# 35                  45-Sistema R. Saladillo                 Río Carcarañá
# 36                 46-Cuenca Emb. San Roque             Lag. Mar Chiquita
# 37                        47-Cuenca R. Soto               Salinas Grandes
# 38                        48- R. Copacabana               Salinas Grandes
# 39            49-Cuenca R. Segundo (Xanaes)             Lag. Mar Chiquita
# 40                 50-Cuenca R. Los Molinos             Lag. Mar Chiquita
# 41     51-Cuenca R. Cuarto (Chocancharagua)                 Río Carcarañá
# 42             52-Sistema Emb. Tigre Muerto                 Río Carcarañá
# 43              53-Cuenca Emb. Cruz del Eje               Salinas Grandes
# 44                   54-Cuenca Emb. La Viña               Salinas Grandes
# 45                        55-Cuenca R. Seco             Lag. Mar Chiquita
# 46              56-Sistema A. Cañada Grande             Lag. Mar Chiquita
# 47            30-Cuenca R. Primero (Suquía)             Lag. Mar Chiquita
# 48                  31-Sistema R. Carcaraña                 Río Carcarañá
# 49     41-Cuenca  R. Tercero (Ctalamochita)                 Río Carcarañá
# 50                     11-Sistema Santa Ana         Río Cuarto- Saladillo
# 51                     21-Sistema Lag. Jume                 Río Carcarañá
# 52          13-Área sin drenaje superficial  Área sin drenaje superficial
# 53                  19-Sistema Canal Devoto                 Río Carcarañá
# 54                    08- Sistema La Picasa                Lag. La Picasa
# 55         29-Sistema Salinas de Ambargasta             Lag. Mar Chiquita
# 56                         57 - La Quebrada                   La Quebrada
# 57                         58 - San Antonio                   San Antonio
# 58                            59 - El Cajón                  Cruz del Eje
#
#                                              geometry  count     max     min  \
# 0   POLYGON ((-62.35514 -31.44984, -62.35400 -31.4...    786  0.0000  0.0000
# 1   POLYGON ((-65.11131 -33.91312, -65.11132 -33.9...   1818  0.0000  0.0000
# 2   POLYGON ((-65.14244 -33.19465, -65.14217 -33.1...    124  0.0000  0.0000
# 3   POLYGON ((-64.87730 -31.63691, -64.87559 -31.6...   1297  1.0625  0.0000
# 4   POLYGON ((-64.50765 -31.48776, -64.50737 -31.4...    345  0.4375  0.0000
# 5   POLYGON ((-64.43029 -31.13925, -64.43001 -31.1...    250  0.3125  0.1250
# 6   POLYGON ((-64.93432 -31.93632, -64.93431 -31.9...   1067  0.8125  0.0000
# 7   POLYGON ((-64.96101 -32.19466, -64.96072 -32.1...   4574  0.1875  0.0000
# 8   POLYGON ((-64.22198 -34.23732, -64.22168 -34.2...   1116  0.0000  0.0000
# 9   POLYGON ((-63.38420 -29.98726, -63.38245 -29.9...   5196  0.0625  0.0000
# 10  POLYGON ((-62.31635 -30.90373, -62.31078 -30.9...   2543  0.0000  0.0000
# 11  POLYGON ((-65.13246 -33.43175, -65.13245 -33.4...   5248  0.0000  0.0000
# 12  POLYGON ((-64.91645 -33.28421, -64.91616 -33.2...   2144  0.0000  0.0000
# 13  POLYGON ((-64.45127 -30.81915, -64.45042 -30.8...   3006  0.1250  0.0000
# 14  POLYGON ((-64.44734 -30.93445, -64.44706 -30.9...   5505  0.1250  0.0000
# 15  POLYGON ((-64.52160 -32.76608, -64.52102 -32.7...   2782  0.0000  0.0000
# 16  POLYGON ((-63.64636 -32.23508, -63.64521 -32.2...   2467  0.0000  0.0000
# 17  POLYGON ((-64.37772 -30.74035, -64.37743 -30.7...   3578  0.0000  0.0000
# 18  POLYGON ((-65.27464 -30.30410, -65.26625 -30.2...   1668  0.1250  0.0000
# 19  POLYGON ((-65.29703 -30.33353, -65.28688 -30.3...   1302  0.1250  0.0000
# 20  POLYGON ((-65.29605 -31.42283, -65.29548 -31.4...   2387  1.0625  0.0000
# 21  POLYGON ((-64.23754 -32.04561, -64.23726 -32.0...  12588  0.0000  0.0000
# 22  POLYGON ((-64.85545 -29.60073, -64.83564 -29.5...   2989  0.7500  0.0000
# 23  POLYGON ((-64.21743 -30.10556, -64.21715 -30.1...   1128  0.5000  0.0000
# 24  POLYGON ((-64.26496 -30.41770, -64.26468 -30.4...   1681  0.1875  0.0000
# 25  POLYGON ((-63.87766 -29.73313, -63.87766 -29.7...   1411  1.4375  0.0000
# 26  POLYGON ((-65.54356 -30.57847, -65.53160 -30.5...   1080  0.0625  0.0000
# 27  POLYGON ((-65.74488 -30.98419, -65.73932 -30.9...   6859  0.4375  0.0000
# 28  POLYGON ((-65.47297 -31.96627, -65.47239 -31.9...   1395  0.1875  0.0000
# 29  POLYGON ((-64.11905 -30.17335, -64.11877 -30.1...    705  0.3125  0.0000
# 30  POLYGON ((-64.23579 -30.36083, -64.23551 -30.3...    881  0.1875  0.0000
# 31  POLYGON ((-64.31275 -32.39250, -64.31188 -32.3...   3440  0.0000  0.0000
# 32  POLYGON ((-65.51189 -30.51082, -65.50111 -30.4...   1551  0.0625  0.0000
# 33  POLYGON ((-64.72950 -32.65501, -64.72921 -32.6...   9604  0.0000  0.0000
# 34  POLYGON ((-65.57957 -31.89825, -65.57929 -31.8...    541  0.4375  0.0000
# 35  POLYGON ((-63.51487 -33.30255, -63.51429 -33.3...   6303  0.0000  0.0000
# 36  POLYGON ((-64.85569 -31.52566, -64.85541 -31.5...   1916  1.0625  0.0625
# 37  POLYGON ((-65.28042 -30.48227, -65.28041 -30.4...    973  1.0625  0.0000
# 38  POLYGON ((-64.97341 -30.18735, -64.96589 -30.1...   2082  0.1250  0.0000
# 39  POLYGON ((-64.36873 -32.02034, -64.36845 -32.0...  14938  0.0000  0.0000
# 40  POLYGON ((-64.51371 -31.82705, -64.51343 -31.8...    483  0.0625  0.0000
# 41  POLYGON ((-65.02394 -32.98852, -65.02356 -32.9...   3629  0.0000  0.0000
# 42  POLYGON ((-65.05410 -33.09850, -65.04991 -33.0...   5933  0.0000  0.0000
# 43  POLYGON ((-64.88367 -31.15661, -64.88225 -31.1...   2227  0.3125  0.0000
# 44  POLYGON ((-65.18110 -31.62134, -65.18082 -31.6...   1052  1.0625  0.0000
# 45  POLYGON ((-64.15652 -30.01184, -64.15624 -30.0...   2056  1.6875  0.0000
# 46  POLYGON ((-63.99288 -29.72572, -63.99260 -29.7...    248  1.6875  0.7500
# 47  POLYGON ((-64.44323 -31.35592, -64.44295 -31.3...   5395  0.4375  0.0000
# 48  POLYGON ((-62.43189 -33.26961, -62.43160 -33.2...   2422  0.0000  0.0000
# 49  POLYGON ((-64.36025 -32.35636, -64.35997 -32.3...   4395  0.0000  0.0000
# 50  POLYGON ((-63.97198 -34.21930, -63.97169 -34.2...    631  0.0000  0.0000
# 51  POLYGON ((-63.23604 -34.03815, -63.23575 -34.0...   4792  0.0000  0.0000
# 52  POLYGON ((-65.10851 -34.11961, -65.10851 -34.1...  14504  0.0000  0.0000
# 53  POLYGON ((-64.31111 -34.20515, -64.31081 -34.2...   9625  0.0000  0.0000
# 54  POLYGON ((-63.55964 -34.22164, -63.55759 -34.2...   2949  0.0000  0.0000
# 55  POLYGON ((-64.75851 -29.56953, -64.75767 -29.5...   3543  2.0625  0.1250
# 56  POLYGON ((-64.35139 -31.14219, -64.35015 -31.1...     44  0.3125  0.1250
# 57  MULTIPOLYGON (((-64.71189 -31.58140, -64.71189...    605  1.0625  0.4375
# 58  POLYGON ((-64.44319 -30.92204, -64.44291 -30.9...    196  0.0625  0.0000
#
#         mean
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.428248
# 4   0.225725
# 5   0.178250
# 6   0.357486
# 7   0.012311
# 8   0.000000
# 9   0.000012
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.031042
# 14  0.044062
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.063399
# 19  0.063652
# 20  0.131939
# 21  0.000000
# 22  0.195111
# 23  0.144725
# 24  0.002119
# 25  0.270907
# 26  0.010243
# 27  0.016976
# 28  0.047581
# 29  0.000887
# 30  0.033627
# 31  0.000000
# 32  0.026717
# 33  0.000000
# 34  0.097736
# 35  0.000000
# 36  0.478601
# 37  0.121981
# 38  0.077329
# 39  0.000000
# 40  0.017340
# 41  0.000000
# 42  0.000000
# 43  0.034070
# 44  0.398051
# 45  0.329523
# 46  1.278478
# 47  0.014041
# 48  0.000000
# 49  0.000000
# 50  0.000000
# 51  0.000000
# 52  0.000000
# 53  0.000000
# 54  0.000000
# 55  0.915150
# 56  0.248580
# 57  0.870351
# 58  0.056441

# %%
cuencas_gdf = cuencas_gdf.loc[cuencas_gdf.index == 49]
cuencas_gdf = cuencas_gdf[['subcuenca', 'subcuenca']]

# %%
cuencas_gdf
# Out:
#                                subcuenca                             subcuenca
# 49  41-Cuenca  R. Tercero (Ctalamochita)  41-Cuenca  R. Tercero (Ctalamochita)

# %%
lista[1][-21:-5]
# Out:
# '2021-02-19Z21:00'

# %%
cuencas_gdf['date'] = datetime.datetime.strptime(lista[1][-21:-5], "%Y-%m-%dZ%H:%M")

# %%
cuencas_gdf
# Out:
#                                subcuenca  \
# 49  41-Cuenca  R. Tercero (Ctalamochita)
#
#                                subcuenca                date
# 49  41-Cuenca  R. Tercero (Ctalamochita) 2021-02-19 21:00:00

# %%
rioii = pd.DataFrame()

# %%
rioii.append(cuencas_gdf, ignore_index=True)
# Out:
#                               subcuenca                             subcuenca  \
# 0  41-Cuenca  R. Tercero (Ctalamochita)  41-Cuenca  R. Tercero (Ctalamochita)
#
#                  date
# 0 2021-02-19 21:00:00

# %% [markdown]
# # Construimos el bucle

# %%
rioii = pd.DataFrame()
lista = getList()
lista.sort()

# %%
for filename in lista:
    cuencas_gdf = integrate_basins(filename)
    cuencas_gdf = cuencas_gdf.loc[cuencas_gdf.index == 49]
    cuencas_gdf = cuencas_gdf[['subcuenca', 'mean']]
    cuencas_gdf['date'] = datetime.datetime.strptime(filename[-21:-5], "%Y-%m-%dZ%H:%M")
    rioii = rioii.append(cuencas_gdf, ignore_index=True)

# %%
rioii.to_csv('ppn_horario_kgm2.csv')

# %%
    cuencas_gdf = integrate_basins(lista[3])
    cuencas_gdf = cuencas_gdf.loc[cuencas_gdf.index == 49]
    cuencas_gdf = cuencas_gdf[['subcuenca', 'subcuenca']]
    cuencas_gdf['date'] = datetime.datetime.strptime(lista[3][-21:-5], "%Y-%m-%dZ%H:%M")
# Out:
# /home/sagus/anaconda3/envs/goes/lib/python3.8/site-packages/rasterstats/io.py:301: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
cuencas_gdf
# Out:
#                                subcuenca  \
# 49  41-Cuenca  R. Tercero (Ctalamochita)
#
#                                subcuenca                date
# 49  41-Cuenca  R. Tercero (Ctalamochita) 2021-02-19 09:00:00

# %%
rioii.append(cuencas_gdf, ignore_index=True)
# Out:
#                               subcuenca                             subcuenca  \
# 0  41-Cuenca  R. Tercero (Ctalamochita)  41-Cuenca  R. Tercero (Ctalamochita)
#
#                  date
# 0 2021-02-19 09:00:00

# %%
test = rioii.groupby(rioii['date'].to_period('m')).cumsum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-23e3540220bb> in <module>
# ----> 1 test = rioii.groupby(rioii['date'].to_period('m')).cumsum().reset_index()
#
# ~/anaconda3/envs/goes/lib/python3.8/site-packages/pandas/core/series.py in to_period(self, freq, copy)
#    4551             new_values = new_values.copy()
#    4552
# -> 4553         new_index = self.index.to_period(freq=freq)
#    4554         return self._constructor(new_values, index=new_index).__finalize__(self)
#    4555
#
# AttributeError: 'RangeIndex' object has no attribute 'to_period'

# %%
rioii.date = pd.to_datetime(rioii.date)

# %%
test = rioii.groupby(rioii.date.to_period('D')).cumsum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-995337cbdd35> in <module>
# ----> 1 test = rioii.groupby(rioii.date.to_period('D')).cumsum().reset_index()
#
# ~/anaconda3/envs/goes/lib/python3.8/site-packages/pandas/core/series.py in to_period(self, freq, copy)
#    4551             new_values = new_values.copy()
#    4552
# -> 4553         new_index = self.index.to_period(freq=freq)
#    4554         return self._constructor(new_values, index=new_index).__finalize__(self)
#    4555
#
# AttributeError: 'RangeIndex' object has no attribute 'to_period'

# %%
data = rioii.groupby([rioii["date"].dt.day]).cumsum()

# %%
data
# Out:
#          mean
# 0    0.000000
# 1    0.012016
# 2    0.326479
# 3    0.822938
# 4    1.581783
# ..        ...
# 124  0.085267
# 125  0.085267
# 126  0.327204
# 127  1.380830
# 128  1.925043
#
# [129 rows x 1 columns]
