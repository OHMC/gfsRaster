# %%
import xarray as xr
import numpy

import matplotlib.pyplot as plt
import pandas as pd
from osgeo import gdal

# %%
data = "../data/ICON/icon_global_icosahedral_single-level_2021030100_002_T_2M.grib2"

# %%
ds = xr.open_dataset(data, engine='cfgrib')
# Out:
# ecCodes provides no latitudes/longitudes for gridType='unstructured_grid'

# %%
t2 = ds.t2m - 273.15

# %%
# copy attributes to get nice figure labels and change Kelvin to Celsius
t2.attrs = ds.t2m.attrs

# %%
t2.attrs["units"] = "deg C"

# %%
t2.plot()

# %%
a = gdal.Open(data)

# %%
a
